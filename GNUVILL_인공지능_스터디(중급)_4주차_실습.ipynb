# %% [markdown]
# <a href="https://colab.research.google.com/github/SYJOO99/GNUVILL_AI/blob/main/GNUVILL_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EC%8A%A4%ED%84%B0%EB%94%94(%EC%A4%91%EA%B8%89)_4%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GNUVILL 인공지능 스터디(중급) 4주차 실습
#
# ---
#
#
#
# 경사하강법 실습

# %% [markdown]
# 기본적인 선형 회귀 방정식
# y = W * x + b(bias)

# %% [markdown]
# ---
#
# ##1. 라이브러리
#
#
# *   **numpy**: 행렬과 다차원 배열을 쉽게 처리하도록 지원하는 파이썬 라이브러리
#
#   자세한 정보는 https://numpy.org/ 참고
#
# *  **matplotlib**: 시각화 관련 함수들을 모아놓은 모듈(그래프를 그려준다!)
#
#   자세한 정보는 https://matplotlib.org/ 참고

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 데이터 만들고 시각화하기
#
# *   **np.random.rand(m, n)**:0 이상 1 미만의 난수 생성

# %%
# 데이터 X, Y 만들기
# 우리가 만들고자 하는 W = 학습률 * ((Y 예측 - Y 실제) * X) 평균
# 우리가 만들고자 하는 b = 학습률 * ((Y 예측 - Y 실제) * 1) 평균

X = np.random.rand(100)
Y = 0.2 * X * 0.5

# %% [markdown]
# *   **plt.figure**: figure(그래프)를 만들어주는 함수
# *   **plt.scatter(X, Y)**: X와 Y에 대해 산포도 작성
# * **plt.show**: 그래프 출력

# %%
# 시각화하기
plt.figure(figsize=(8, 6)) # x축 사이즈, y축 사이즈
plt.scatter(X, Y)
plt.show()

def plot_prediction(pred, y):
  plt.figure(figsize=(8, 6))
  plt.scatter(X, Y)
  plt.scatter(X, pred)
  plt.show()

# %% [markdown]
# ## 3. 경사하강법 구현

# %% [markdown]
# *   **np.random.uniform**: 균등 분포 정보를 생성하여 array에 만들기

# %%
# 가중치(W)와 바이어스(b) 초기화
W = np.random.uniform(-1, 1)
b = np.random.uniform(-1, 1)

# %%
# 학습률 설정
learning_rate = 0.7

# %% [markdown]
# *   **epoch**:
#
#   한 번의 epoch는 인공 신경망에서 전체 데이터 셋에 대해 forward pass/backward pass 과정을 거친 것.
#
#   즉, 전체 데이터 셋에 대해 한 번 학습을 완료한 상태
#
#
# ---
#
#
# *  **np.abs**: 절댓값을 구하는 함수
# * **.mean()**: 평균을 구하는 함수
# * **plot_prediction(a, b)**: 예측한 두 데이터 a, b에 대한 그래프를 한 그래프에 동시에 출력(함수)

# %%
for epoch in range(100):
  Y_Pred = W * X + b

  error = np.abs(Y_Pred - Y).mean()
  if error < 0.001:
    break
  
  # 경사 하강법
  W_grad = learning_rate * ((Y_Pred - Y) * X).mean()
  b_grad = learning_rate * (Y_Pred - Y).mean()

  # W, b 값 갱신
  W = W - W_grad
  b = b - b_grad

  if epoch % 5 == 0: # 중간과정 시각화
    Y_Pred = W * X + b
    plot_prediction(Y_Pred, Y)
